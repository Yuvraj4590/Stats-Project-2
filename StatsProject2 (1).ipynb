# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)
df.head
# Out:
# <bound method NDFrame.head of       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
# Display the first few rows and summary statistics
df.head(15)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    18606  Not Specified      0.01        2.88           0.50            2
# 1    20847           High      0.01        2.84           0.93            3
# 2    23086  Not Specified      0.03        6.68           6.15            3
# 3    23087  Not Specified      0.01        5.68           3.60            3
# 4    23088  Not Specified      0.00      205.99           2.50            3
# 5    23597         Medium      0.09       55.48          14.30            3
# 6    25549            Low      0.08      120.97          26.30            3
# 7    20228  Not Specified      0.02      500.98          26.00            5
# 8    19483            Low      0.08        6.48           6.81            5
# 9    24782           High      0.01       90.24           0.99            6
# 10   24563       Critical      0.07        6.48           6.60            6
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Handle missing values
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
Q1. Data Handling:
(a) How would you handle missing values in a dataset? Describe at least two methods.
Ans :
Mean/Median/Mode :
Mean :-In the available data replacng the missing vlues for that variable this is suitable for numarical data.
Example: If a column of test scores has missing values, replace each missing value with the average test score of the non-missing values.
                                                                                                    
Median: Replace missing values with the median of the available data. This is useful for numerical data, especially when the data is skewed.
Example: In a column of income data with some missing values, replace the missing values with the median income, which is less sensitive to outliers than the mean.

Mode: Replace missing values with the mode (most frequent value) of the available data. This is typically used for categorical data.
Example: In a column of customer satisfaction ratings, fill in missing values with the most frequently recorded rating.
                                                                                                    
Row Deletion: Removes entire rows with one or more missing values. This method is useful when the missing data is minimal compared to the dataset, 
     ensuring a clean dataset without missing values.

(b) Explain why it might be necessary to convert data types before performing an
analysis.

# %%
product_base_margen1=df['Product Base Margin'].median()
product_base_margen1
# Out:
# 0.52

# %%
import pandas as pd
import numpy as np
# Replace NaN values with the replacement value
df['Product Base Margin'] = df['Product Base Margin'].fillna(product_base_margen1)
df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
# Convert data types if necessary

import pandas as pd

# Load your DataFrame (replace with your actual file path)
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Display initial data types
print("Initial Data Types:")
print(df.dtypes)

# Handle missing values if necessary
# Example: Replace NaNs with a default value for integer conversion
df['Product Base Margin'] = df['Product Base Margin'].fillna(0)

# Convert to integer (assuming all values are suitable for integer type)
df['Product Base Margin'] = df['Product Base Margin'].astype(int)

# Convert to float (useful if you need more precision)
df['Sales'] = df['Sales'].fillna(0).astype(float)  # Replace NaNs with 0 before conversion

# Convert to categorical type
df['Category'] = df['Category'].astype('category')

# Convert to datetime if necessary (Example)
# df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Display the updated data types
("\nUpdated Data Types:")
(df.dtypes)
# Out:
# Initial Data Types:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# ...

# %%
# Create any new columns needed for analysis
# Example: Create dummy variables for the 'Category' column
import pandas as pd

# Load your DataFrame (replace with your actual file path)
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Calculate profit margin percentage
df['Profit Margin (%)'] = (df['Profit'] / df['Sales']) * 100

# Calculate sales growth compared to the previous row
df['Sales Growth'] = df['Sales'].diff()

# Calculate total revenue including a hypothetical tax rate of 10%
df['Total Revenue'] = df['Sales'] * 1.10
(df.head())
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   Postal Code Order Date  Ship Date    Profit Quantity ordered new    Sales  \
# ...

# %%
# Univariate analysis
import matplotlib.pyplot as plt
import seaborn as sns

categorical_cols = df.select_dtypes(include=['object']).columns

# Plot frequency counts for each categorical variable
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
Q1. Univariate and Bivariate Analysis
(a) What is univariate analysis, and what are its key purposes?
## Univariate analysis is a statistical technique that analyses and summarises the features of a single variable
Key Purposes of Univariate analysis:- Measure such as the mean mode and median and identify the center of point of the data
Frequency Distribution :-Observing renges of values occure in the data set
Data Visualization: prepairing Plots histograms ,pie charts,bar charts,box plots, distrubution and summary statistics data.

# %%
Q3 (B) Explain the difference between univariate and bivariate analysis. Provide an
example of each
Both methods of analysis are important for understanding data: univariate analysis analyses individual variables, 
whereas bivariate analysis analyses interactions and correlations between variables.

# %%
# Bivariate analysis
(df.columns)
import pandas as pd
import matplotlib.pyplot as plt
data = {'Region': [5000, 6000, 7000, 8000, 9000],
    'Profit': [30, 40, 50, 60, 70]}
df = pd.DataFrame(data)
plt.scatter(df['Region'], df['Profit'])
plt.xlabel('Region')
plt.ylabel('Profit')
plt.title('Scatter Plot of Region vs Profit')
plt.show()

# %%
# Summary statistics for key variables

import pandas as pd
# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# variables are numeric
df['Sales'] = pd.to_numeric(df['Sales'],errors='coerce')
df['Quantity ordered new'] = pd.to_numeric(df['Quantity ordered new'],errors='coerce')
df['Profit'] = pd.to_numeric(df['Profit'],errors='coerce')
# Drop rows with NaN values in key variables
df = df.dropna(subset=['Sales','Quantity ordered new', 'Profit'])

# summary statistics for key variables
summary_stats = df[['Sales','Quantity ordered new','Profit']].describe()

("Summary Statistics for Key Variables:")
summary_stats
# Out:
#                Sales  Quantity ordered new        Profit
# count    9426.000000           9426.000000   9426.000000
# mean      949.706272             13.798430    139.236410
# std      2598.019818             15.107688    998.486483
# min         1.320000              1.000000 -16476.838000
# 25%        61.282500              5.000000    -74.017375
# 50%       203.455000             10.000000      2.567600
# 75%       776.402500             17.000000    140.243850
# max    100119.160000            170.000000  16332.414000

# %%
# Grouped statistics
import pandas as pd
# Load DataFrame
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Group by 'Category' and calculate basic statistics
category_stats = df.groupby('Product Category').agg(
    Total_Sales=pd.NamedAgg(column='Sales', aggfunc='sum'),
    Average_Profit=pd.NamedAgg(column='Profit', aggfunc='mean')).reset_index()

("Product Category Statistics:")
(Product Category_stats)

# Group by 'Category' and 'Region' for more detailed statistics
category_region_stats = df.groupby(['Product Category', 'Region']).agg(
    Average_Sales=pd.NamedAgg(column='Sales', aggfunc='mean'),
    Average_Profit=pd.NamedAgg(column='Profit', aggfunc='mean'),
    Total_Sales=pd.NamedAgg(column='Sales', aggfunc='sum'),
    Total_Profit=pd.NamedAgg(column='Profit', aggfunc='sum')).reset_index()

("\nProduct Category and Region Statistics:"),
(Product Category_region_stats)

# Apply a custom aggregation function
def range_func(x):
    return x.max() - x.min()

custom_stats = df.groupby('Category').agg(
    Sales_Range=pd.NamedAgg(column='Sales', aggfunc=range_func),
    Profit_Median=pd.NamedAgg(column='Profit', aggfunc='median')).reset_index(),

("\nCustom Statistics:"),
(custom_stats),
# Calculate cumulative sales within each 'Category'
df['Cumulative_Sales'] = df.groupby('Product Category')['Sales'].cumsum()

("\nDataFrame with Cumulative Sales:")
df.head
# Create a pivot table for a summary
pivot_table = pd.pivot_table(df, 
                             values=['Sales', 'Profit'], 
                             index=['Product Category', 'Region'], 
                             aggfunc={'Sales': 'sum', 'Profit': 'mean'}),

("\nPivot Table:")
(pivot_table)
# Out:
#   Cell In[18], line 13
#     (Product Category_stats)
#      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Conclusion
#
# - Summary of key findings.
# - Insights based on the analysis.

# %% [markdown]
# ## Additional Statistical Analysis

# %%
from scipy.stats import ttest_ind, chi2_contingency

# Example: T-test for sales in different regions
import pandas as pd
from scipy.stats import ttest_ind

# Sample DataFrame with sales data for different regions
data = {'Sales': [100, 150, 200, 250, 300, 350, 400, 450, 500,600],
    'Region': ['North', 'North', 'North', 'South', 'South', 'South', 'North', 'South', 'North', 'South']}
df = pd.DataFrame(data)

#  each region of sales data
sales_north = df[df['Region'] == 'North']['Sales']
sales_south = df[df['Region'] == 'South']['Sales']

# Perform the T-test
t_stat, p_value = ttest_ind(sales_north, sales_south)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Interpretation
if p_value < 0.05:
    print("Reject the null hypothesis: There is a significant difference in sales between North and South regions.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in sales between North and South regions.")
# Out:
# T-statistic: -1.2152872405004
# P-value: 0.2589021750101298
# Fail to reject the null hypothesis: There is no significant difference in sales between North and South regions.

# %%
Q 2. Statistical Analysis:
(a)What is a T-test, and in what scenarios would you use it? Provide an example based on sales data.
Suppose Sales Excutive want to figure out if a new advertising campaign resulted in a considerable rise in monthly
sales compared to the preceding quarter. You have sales data for the last six months prior to the campaign and 
the first six months after the campaign began.
# Formulate hypotheses:
    The null hypothesis (H0) states that there is no significant change in mean sales before and after the campaign.
    (Mean Sales Before equals Mean Sales After)
Alternative Hypothesis (H1): There is a significant difference in average sales before and after the campaign. (Mean sales before vs. after)

Collect sales data before the campaign: [10,000, 12,000, 11,500, 9,800, 10,500, 11,000].
Following Campaign Sales Data: [13,000, 14,500, 15,000, 13,800, 14,200, 15,500]
Perform the T-test:
Calculate the average and standard deviation for both periods.
The T-statistic and p-value can be calculated using statistical software or a T-test procedure.
Interpret the results:

T-Statistic and P-Value: These values will tell you whether the difference in means is statistically significant. 
Generally, a p-value less than 0.05 indicates that the difference is significant.
##calculate the following:
Mean Sales Before Campaign: $10,583.33
Mean Sales After Campaign: $14,000
Standard Deviations and Sample Sizes: Assume you compute these or use statistical software.
Using a T-test calculation (either manually or via software), you find:

T-Statistic: 4.5 (hypothetical value)
P-Value: 0.001 (hypothetical value)

# %%
 # Example: Chi-square test for independence between Ship Mode and Customer Segment

import pandas as pd
import scipy.stats as stats

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Preview the data to understand its structure
print(df.head())

# Create a contingency table for Shipping Mode and Customer Segment
contingency_table = pd.crosstab(df['Ship Mode'], df['Customer Segment'])

# Perform the Chi-square test
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

# Print results
print(f'Chi-square Statistic: {chi2}')
print(f'p-value: {p}')
print(f'Degrees of Freedom: {dof}')
print(f'Expected Frequencies Table:\n{expected}')

# Interpretation
alpha = 0.05
if p < alpha:
    print('Reject the null hypothesis: There is a significant association between Shipping Mode and Customer Segment.')
else:
    print('Fail to reject the null hypothesis: There is no significant association between Shipping Mode and Customer Segment.')
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
# Selecting only numeric columns for correlation matrix

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

#  column data types to inspect
("Data types of columns:")
(df.dtypes)

# numeric columns only
numeric_df = df.select_dtypes(include='number')

("\nNumeric columns in the DataFrame:")
(numeric_df.columns)

# correlation matrix
correlation_matrix = numeric_df.corr()

("\nCorrelation Matrix:")
(correlation_matrix)

# Set the style of the visualization
sns.set(style='whitegrid')

# Plotting the correlation matrix
plt.figure(figsize=(11, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)

# Add titles and labels
plt.title('Correlation Matrix of Numeric Columns', fontsize=10)
plt.show()

# %%
# Plotting sales trends over time
data = [ {'Order Date': '2023-01-11', 'Sales': 200, 'Profit': 50},
    {'Order Date': '2023-01-25', 'Sales': 150, 'Profit': 30},]
# Create DataFrame
df = pd.DataFrame(data)

# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['YearMonth'] = df['Order Date'].dt.to_period('M')

# Aggregate sales data
monthly_sales = df.groupby('YearMonth')['Sales'].sum().reset_index()
monthly_sales['YearMonth'] = monthly_sales['YearMonth'].dt.to_timestamp()

# Plotting
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 9))
plt.plot(monthly_sales['YearMonth'], monthly_sales['Sales'], marker='o', linestyle='-', color='b')
plt.title('Monthly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Resample sales data by month

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)
# Convert 'Order Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Set 'Order Date' as the index
df.set_index('Order Date', inplace=True)

# Resample by month and sum sales
monthly_sales = df['Sales'].resample('M').sum()

# Plotting the monthly sales
plt.figure(figsize=(15, 6))
monthly_sales.plot(kind='line', marker='o', linestyle='-', color='b')
plt.title('Monthly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.xticks(rotation= 55)
plt.tight_layout()
plt.show()

# %%
# Plotting profit trends over time

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Convert 'Order Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Set 'Order Date' as the index
df.set_index('Order Date', inplace=True)

# Resample by month and sum profit
monthly_profit = df['Profit'].resample('M').sum()

# Plotting the monthly profit
plt.figure(figsize=(15, 7))
monthly_profit.plot(kind='line', marker='o', linestyle='-', color='r')
plt.title('Monthly Profit Trend')
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.grid(True)
plt.xticks(rotation=65)
plt.tight_layout()
plt.show()

# %%
# Identifying top-performing product categories based on total sales and profit

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Display the first few rows to understand the structure
print(df.head())

# Display column names to ensure relevant columns are present
print("Column names in the DataFrame:")
print(df.columns)

# Ensure relevant columns exist and aggregate data
if 'Category' in df.columns and 'Sales' in df.columns and 'Profit' in df.columns:
    # Aggregate total sales and profit by product category
    sales_by_category = df.groupby('Category')['Sales'].sum().reset_index()
    profit_by_category = df.groupby('Category')['Profit'].sum().reset_index()

    # Sort the categories by total sales and profit
    sales_by_category = sales_by_category.sort_values(by='Sales', ascending=False)
    profit_by_category = profit_by_category.sort_values(by='Profit', ascending=False)

    # Plotting total sales by product category
    plt.figure(figsize=(8, 6))
    sns.barplot(x='Sales', y='Category', data=sales_by_category, palette='viridis')
    plt.title('Total Sales by Product Category')
    plt.xlabel('Total Sales')
    plt.ylabel('Product Category')
    plt.grid(axis='x')
    plt.show()

    # Plotting total profit by product category
    plt.figure(figsize=(15, 6))
    sns.barplot(x='Profit', y='Category', data=profit_by_category, palette='magma')
    plt.title('Total Profit by Product Category')
    plt.xlabel('Total Profit')
    plt.ylabel('Product Category')
    plt.grid(axis='x')
    plt.show()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
# Plotting total sales by product category

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)
(df.columns)

# Ensure that the 'Sales' column is numeric
df['Sales'] = pd.to_numeric(df['Sales'])

# Replace 'Category' with the actual column name, e.g., 'Product Category'
category_col = 'Product Category'  # Update this to the correct column name

# Group by the correct column name and sum 'Sales'
category_sales = df.groupby(category_col)['Sales'].sum().reset_index()

# Sort the categories by total sales in descending order
category_sales = category_sales.sort_values(by='Sales', ascending=False)

# Set the style of the visualization
sns.set(style='whitegrid')

# Create a bar plot for total sales by category
plt.figure(figsize=(9, 6))
sns.barplot(data=category_sales, x=category_col, y='Sales', palette='viridis')

# Add titles and labels
plt.title('Total Sales by Product Category', fontsize=12)
plt.xlabel('Product Category', fontsize=9)
plt.ylabel('Total Sales', fontsize=9)
plt.xticks(rotation=55)  # Rotate x labels for better readability

# Show the plot
plt.show()

# %%
# Plotting total profit by product category

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)
(df.columns)

#'Sales' column is numeric
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')

#'Profit' column is numeric
df['Profit'] = pd.to_numeric(df['Profit'],

# Replace 'Product Category' with the actual column name if different
category_col = 'Product Category'  #this to the correct column name

# Group by the correct column name and sum 'Sales'
category_sales = df.groupby(category_col)['Sales'].sum().reset_index()

# total sales in descending order
category_sales = category_sales.sort_values(by='Sales', ascending=False)

sns.set(style='whitegrid')

# Create bar plot for total sales by category
plt.figure(figsize=(11, 5))
sns.barplot(data=category_sales, x=category_col, y='Sales', palette='viridis')

#  titles Names and labels
plt.title('Total Sales by Product Category', fontsize=12)
plt.xlabel('Product Category', fontsize=9)
plt.ylabel('Total Sales', fontsize=9)
plt.xticks(rotation=55) 
# Rotate x labels for better readability
plt.show()
# Out:
#   Cell In[33], line 16
#     df['Profit'] = pd.to_numeric(df['Profit'],
#                                 ^
# SyntaxError: '(' was never closed

# %%
# Generating summary statistics for each region

# Display summary statistics

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Print column names to verify
print(df.columns)

# numerical columns are numeric
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
df['Profit'] = pd.to_numeric(df['Profit'],errors='coerce')

# Replace 'Region' with the actual column name if different
region_col = 'Region'  # Update this to the correct column name

# Group by 'Region' and calculate summary statistics
summary_statistics = df.groupby(region_col).agg({
    'Sales': ['sum', 'mean', 'median', 'std', 'min', 'max'],
    'Profit': ['sum', 'mean', 'median', 'std', 'min', 'max'],
}).reset_index()

# Rename columns for clarity
summary_statistics.columns = [' '.join(col).strip() for col in summary_statistics.columns.values]

# Display the summary statistics
(summary_statistics)
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')
#     Region   Sales sum   Sales mean  Sales median    Sales std  Sales min  \
# 0  Central  2540341.62   876.282035       203.370  2041.342685       2.24
# 1     East  2422804.68  1058.455518       225.140  2802.669839       1.32
# 2    South  1597346.22   817.475036       180.375  2173.877698       2.66
# 3     West  2391438.80  1047.039755       204.730  3258.451329       1.62
#
#    Sales max     Profit sum  Profit mean  Profit median   Profit std  \
# 0   32589.59  519825.567067   179.312027         6.1400   933.585650
# ...

# %%
# Visualizing the correlation between sales and profit

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Print column names to verify
print(df.columns)

# Ensure that the numerical columns are numeric
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
df['Profit'] = pd.to_numeric(df['Profit'], errors='coerce')

# Replace 'Region' with the actual column name if different
region_col = 'Region'  # Update this to the correct column name

# Group by 'Region'
grouped = df.groupby(region_col).agg({ 'Sales': ['sum', 'mean', 'median', 'std', 'min', 'max'],
    'Profit': ['sum', 'mean', 'median', 'std', 'min', 'max'],}).reset_index()

# Clarity for Rename
grouped.columns = [' '.join(col).strip() for col in grouped.columns.values]

# Display the summary statistics
print(grouped)

#  visualization
sns.set(style='whitegrid')

# Plot mean sales and profit by region
plt.figure(figsize=(13, 6))

# Mean Sales
plt.subplot(1, 2, 1)
sns.barplot(data=grouped, x=region_col, y='Sales mean', palette='viridis')
plt.title('Mean Sales by Region')
plt.xlabel('Region')
plt.ylabel('Mean Sales')
plt.xticks(rotation=35)

# Mean Profit
plt.subplot(1, 2, 2)
sns.barplot(data=grouped, x=region_col, y='Profit mean', palette='viridis')
plt.title('Mean Profit by Region')
plt.xlabel('Region')
plt.ylabel('Mean Profit')
plt.xticks(rotation=35)
plt.show()
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')
#     Region   Sales sum   Sales mean  Sales median    Sales std  Sales min  \
# 0  Central  2540341.62   876.282035       203.370  2041.342685       2.24
# 1     East  2422804.68  1058.455518       225.140  2802.669839       1.32
# 2    South  1597346.22   817.475036       180.375  2173.877698       2.66
# 3     West  2391438.80  1047.039755       204.730  3258.451329       1.62
#
#    Sales max     Profit sum  Profit mean  Profit median   Profit std  \
# 0   32589.59  519825.567067   179.312027         6.1400   933.585650
# ...

# %%
# Displaying the correlation coefficient

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Ensure that 'Sales' and 'Profit' are numeric
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
df['Profit'] = pd.to_numeric(df['Profit'], errors='coerce')

# Calculate the correlation coefficient
correlation = df[['Sales', 'Profit']].corr().iloc[0, 1]

# Print the correlation coefficient
(f'Correlation coefficient between Sales and Profit: {correlation:.2f}')

# Set the style of the visualization
sns.set(style='whitegrid')

# Create a scatter plot with a regression line
plt.figure(figsize=(12, 7))
sns.regplot(data=df, x='Sales', y='Profit', scatter_kws={'s':50}, line_kws={'color':'red'})

# Add titles and labels
plt.title('Scatter Plot of Sales vs. Profit', fontsize=14)
plt.xlabel('Sales', fontsize=10)
plt.ylabel('Profit', fontsize=10)
plt.show()

# %%
# Analyzing seasonal sales trends

# Grouping sales data by month and year

# Plotting seasonal sales trends

# Comparing sales across different ship modes

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Ensure 'Ship Date' column is datetime type
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')

# 'Ship Date' couldn't be converted
df = df.dropna(subset=['Ship Date'])

# Set 'Ship Date' as the index
df.set_index('Ship Date', inplace=True)

# Grouping sales data by month and year
monthly_sales = df['Sales'].resample('M').sum()

("Monthly Sales Data:")
(monthly_sales.head())  # Print first few rows for verification
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# Ensure 'Ship Date' column is datetime type
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')

# 'Ship Date' couldn't be converted
df = df.dropna(subset=['Ship Date'])

# Set 'Ship Date' as the index
df.set_index('Ship Date', inplace=True)

# Grouping sales data by month and year
monthly_sales = df['Sales'].resample('M').sum()

("Monthly Sales Data:")
(monthly_sales.head())  # Print first few rows for verification
# Out:
# Ship Date
# 2010-01-31    126257.81
# 2010-02-28    142996.24
# 2010-03-31    145478.01
# 2010-04-30    115700.23
# 2010-05-31    109756.88
# Freq: M, Name: Sales, dtype: float64

# %%
# Ensure column names are clean

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_').str.replace('-', '_')

# Display cleaned column names
("Cleaned Column Names:")
(df.columns)
# Out:
# Index(['row_id', 'order_priority', 'discount', 'unit_price', 'shipping_cost',
#        'customer_id', 'customer_name', 'ship_mode', 'customer_segment',
#        'product_category', 'product_sub_category', 'product_container',
#        'product_name', 'product_base_margin', 'region', 'state_or_province',
#        'city', 'postal_code', 'order_date', 'ship_date', 'profit',
#        'quantity_ordered_new', 'sales', 'order_id'],
#       dtype='object')

# %%
# Print column names to verify
# Ensure 'Ship Date' column is datetime type
# Dropping rows where 'Ship Date' couldn't be converted
# Resample sales data by month

import pandas as pd

# Load the dataset
file_path = 'sample-superstore-subset-excel.xlsx'
df = pd.read_excel(file_path)

# column names for verify
("Column names in the DataFrame:")
(df.columns)

# 'Ship Date' column is datetime type
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')

# Dropping rows where 'Ship Date' couldn't be converted
df = df.dropna(subset=['Ship Date'])

# Set 'Ship Date' as the index
df.set_index('Ship Date', inplace=True)

# Resample sales data by month and sum the sales
monthly_sales = df['Sales'].resample('M').sum()

("Monthly Sales Data:")
(monthly_sales)
# Out:
# Ship Date
# 2010-01-31    126257.81
# 2010-02-28    142996.24
# 2010-03-31    145478.01
# 2010-04-30    115700.23
# 2010-05-31    109756.88
# 2010-06-30    120919.46
# 2010-07-31    130921.20
# 2010-08-31    204815.20
# 2010-09-30    113548.59
# 2010-10-31    271748.44
# 2010-11-30    209885.57
# 2010-12-31    213925.69
# 2011-01-31    126987.93
# 2011-02-28     87950.17
# 2011-03-31     65068.93
# 2011-04-30     75960.54
# 2011-05-31    144368.81
# 2011-06-30    120091.47
# 2011-07-31    121480.95
# 2011-08-31    117987.72
# 2011-09-30    285433.41
# 2011-10-31    260563.51
# 2011-11-30    326863.96
# 2011-12-31    195801.11
# 2012-01-31    125421.85
# 2012-02-29     97483.81
# 2012-03-31    103970.37
# 2012-04-30    116290.72
# 2012-05-31    162398.24
# 2012-06-30    142223.10
# 2012-07-31    162353.63
# 2012-08-31    142585.69
# 2012-09-30    202582.26
# 2012-10-31    181586.65
# 2012-11-30    532586.62
# 2012-12-31    284845.96
# 2013-01-31    207012.77
# 2013-02-28    127667.27
# ...
